# %%
import pandas as pd

df = pd.read_parquet('./archivos_csv/Historico precios con dolar.parquet')
df
# Out:
#              Fecha  id_producto   Precio Ars  id_empresa  \
# 0       2001-01-01           21    45.790001        5572
# 1       2001-07-20            2    22.360001        1397
# 2       2001-08-20            6    21.990000         732
# 3       2001-10-20            3    44.080002        8681
# 4       2002-02-20           19    75.139999        3745
# ...            ...          ...          ...         ...
# 1296925 2024-04-01           19   955.000000        8092
# 1296926 2024-04-01           21  1149.000000        8092
# 1296927 2024-04-01           19   985.000000        1376
# 1296928 2024-04-02           19   968.000000        3720
# 1296929 2024-04-02            3  1034.000000        8079
#
#          Cotizacion_DolarBlue  Precio_dolarBlue  Cotizacion_DolarOficial  \
# 0                        2.95         15.520000                 1.600000
# 1                        2.95          7.580000                 1.600000
# 2                        2.95          7.450000                 1.600000
# 3                        2.95         14.940000                 1.600000
# 4                        2.20         34.150002                 1.600000
# ...                       ...               ...                      ...
# 1296925               1010.00          0.950000               901.630005
# 1296926               1010.00          1.140000               901.630005
# 1296927               1010.00          0.980000               901.630005
# 1296928               1010.00          0.960000               901.630005
# 1296929               1010.00          1.020000               901.630005
#
#          Precio_dolarOficial
# 0                  28.620001
# 1                  13.980000
# 2                  13.740000
# 3                  27.549999
# 4                  46.959999
# ...                      ...
# 1296925             1.060000
# 1296926             1.270000
# 1296927             1.090000
# 1296928             1.070000
# 1296929             1.150000
#
# [1296930 rows x 8 columns]

# %% [markdown]
# ## Corrección de los datos
#
# Se detectaron errores en los valores desde el 2001 a 2016, por lo cual se buscaron los valores correctos para cada periodo.
#
# Ahora se prodera a hacer el cambio y correccion manual de cada uno

# %%
precios_actualizados = [0.54, 1.09, 0.60, 1.18, 1.19, 1.25, 1.58, 1.28, 1.55, 1.42, 1.38, 1.42, 1.57, 1.27, 1.18, 1.63, 1.35, 1.48, 1.68, 1.35, 2.20, 2.00, 2.10, 2.50, 2.40, 2.10, 2.00, 2.40, 2.10, 2.50, 2.00, 2.40, 0.75, 1.95, 1.60, 1.68, 1.55, 2.20, 2.60, 3.00, 3.10, 2.70, 3.10, 3.50, 3.50, 3.70, 3.80, 4.10, 5.00, 4.50, 5.50, 5.40, 5.10, 4.70, 4.80, 5.00, 5.40, 4.80, 4.70, 4.70, 5.40, 5.10, 4.80, 5.10, 4.80, 4.70, 5.40, 12.00, 6.00, 12.00, 5.30, 5.10, 15.69]

# %%
for i in range(len(precios_actualizados)):
    df.loc[i, 'Precio Ars'] = float(precios_actualizados[i])
    df.loc[i, 'Precio_dolarBlue'] = float(df.loc[i, 'Precio Ars'] / df.loc[i, 'Cotizacion_DolarBlue'])
    df.loc[i, 'Precio_dolarOficial'] = float(df.loc[i, 'Precio Ars'] / df.loc[i, 'Cotizacion_DolarOficial'])

df
# Out:
#              Fecha  id_producto  Precio Ars  id_empresa  Cotizacion_DolarBlue  \
# 0       2001-01-01           21        0.54        5572                  2.95
# 1       2001-07-20            2        1.09        1397                  2.95
# 2       2001-08-20            6        0.60         732                  2.95
# 3       2001-10-20            3        1.18        8681                  2.95
# 4       2002-02-20           19        1.19        3745                  2.20
# ...            ...          ...         ...         ...                   ...
# 1296925 2024-04-01           19      955.00        8092               1010.00
# 1296926 2024-04-01           21     1149.00        8092               1010.00
# 1296927 2024-04-01           19      985.00        1376               1010.00
# 1296928 2024-04-02           19      968.00        3720               1010.00
# 1296929 2024-04-02            3     1034.00        8079               1010.00
#
#          Precio_dolarBlue  Cotizacion_DolarOficial  Precio_dolarOficial
# 0                0.183051                 1.600000              0.33750
# 1                0.369492                 1.600000              0.68125
# 2                0.203390                 1.600000              0.37500
# 3                0.400000                 1.600000              0.73750
# 4                0.540909                 1.600000              0.74375
# ...                   ...                      ...                  ...
# 1296925          0.950000               901.630005              1.06000
# 1296926          1.140000               901.630005              1.27000
# 1296927          0.980000               901.630005              1.09000
# 1296928          0.960000               901.630005              1.07000
# 1296929          1.020000               901.630005              1.15000
#
# [1296930 rows x 8 columns]

# %%
df.to_parquet('./archivos_csv/Historico precios con dolar.parquet', index=False)
